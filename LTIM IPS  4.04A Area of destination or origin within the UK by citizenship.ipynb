# %% [markdown]
# Datasheet 4.04A: Area of destination or origin within the UK by citizenship

# %%
from databaker.framework import *
import pandas as pd

# %%
from pathlib import Path

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

# %run lib/scrape_ons.ipynb

metadata = scrape('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/ipsareaofdestinationororiginwithintheukbycitizenship')
metadata
# Out:
# {'about': 'International Passenger Survey detailed estimates of Long-Term International Migration: Area of destination or origin within the UK by citizenship. UK, Underlying datasheet 4.',
#  'fileURL': 'https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsareaofdestinationororiginwithintheukbycitizenship/2016/underlyingdatasheet4.04ipsareaofdestinationororiginwithintheukbycitizenship2016.xls',
#  'mailto': 'mailto:migstatsunit@ons.gsi.gov.uk',
#  'nextRelease': datetime.date(2018, 11, 29),
#  'releaseDate': datetime.date(2017, 11, 30),
#  'title': 'International Passenger Survey\xa04.04, area\xa0of\xa0destination or origin within the UK by citizenship'}

# %% [markdown]
# https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsareaofdestinationororiginwithintheukbycitizenship/2016/underlyingdatasheet4.04ipsareaofdestinationororiginwithintheukbycitizenship2016.xls

# %%
inputFile = sourceFolder / 'data.xls'
response = session.get(metadata['fileURL'])
# with open(inputFile, 'wb') as f:
#   f.write(response.content)
# # tab = loadxlstabs(inputFile, sheetids='Datasheet 4.04A')[0]

# %%
# response.content

# %%
xls = pd.ExcelFile(BytesIO(response.content))
df1 = pd.read_excel(xls, 'Datasheet 4.04A', header = 7)

# %%
df1
# Out:
#            Software Readable Column Label (See Notes)  \
# 0                                              Inflow
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                            Outflow
# ...

# %%
observations = df1.iloc[:, 4:]
observations.head()
# Out:
#                    Row Label  CIT All EST  CIT All CI  CIT British EST  \
# 0     INFLOW, United Kingdom        526.6        34.4             71.7
# 1      INFLOW, Great Britain        520.8        33.7             71.7
# 2  INFLOW, England and Wales        488.4        32.7             68.0
# 3            INFLOW, England        470.3        32.0             66.0
# 4              INFLOW, Wales         18.1         6.8              2.0
#
#    CIT British CI  CIT Non-British EST  CIT Non-British CI  \
# 0            13.9                454.9                31.5
# 1            13.9                449.1                30.7
# 2            13.7                420.4                29.7
# 3            13.4                404.3                29.1
# 4             2.6                 16.1                 6.3
#
#    CIT British or British Overseas EST  CIT British or British Overseas CI  \
# 0                                 72.9                                14.1
# ...

# %%
new_table = pd.melt(observations,
                       ["Row Label"],
                       var_name="Column label",
                       value_name="Value")

# %%
new_table.head(50)
# Out:
#                             Row Label Column label  Value
# 0              INFLOW, United Kingdom  CIT All EST  526.6
# 1               INFLOW, Great Britain  CIT All EST  520.8
# 2           INFLOW, England and Wales  CIT All EST  488.4
# 3                     INFLOW, England  CIT All EST  470.3
# 4                       INFLOW, Wales  CIT All EST   18.1
# 5                    INFLOW, Scotland  CIT All EST   32.4
# 6                  INFLOW, North East  CIT All EST   18.9
# 7                  INFLOW, North West  CIT All EST   43.8
# 8    INFLOW, Yorkshire and The Humber  CIT All EST   37.7
# 9               INFLOW, East Midlands  CIT All EST     29
# 10              INFLOW, West Midlands  CIT All EST   40.4
# 11                       INFLOW, East  CIT All EST     50
# 12                     INFLOW, London  CIT All EST  143.7
# 13                 INFLOW, South East  CIT All EST   74.3
# 14                 INFLOW, South West  CIT All EST   32.4
# ...

# %%
new_table.shape
# Out:
# (4020, 3)

# %%
new_table.dropna(inplace=True)

# %%
new_table = new_table[new_table['Value'] != '.']

# %%
new_table = new_table[new_table['Value'] != '0']

# %%
new_table.head(50)
# Out:
#                             Row Label Column label  Value
# 0              INFLOW, United Kingdom  CIT All EST  526.6
# 1               INFLOW, Great Britain  CIT All EST  520.8
# 2           INFLOW, England and Wales  CIT All EST  488.4
# 3                     INFLOW, England  CIT All EST  470.3
# 4                       INFLOW, Wales  CIT All EST   18.1
# 5                    INFLOW, Scotland  CIT All EST   32.4
# 6                  INFLOW, North East  CIT All EST   18.9
# 7                  INFLOW, North West  CIT All EST   43.8
# 8    INFLOW, Yorkshire and The Humber  CIT All EST   37.7
# 9               INFLOW, East Midlands  CIT All EST     29
# 10              INFLOW, West Midlands  CIT All EST   40.4
# 11                       INFLOW, East  CIT All EST     50
# 12                     INFLOW, London  CIT All EST  143.7
# 13                 INFLOW, South East  CIT All EST   74.3
# 14                 INFLOW, South West  CIT All EST   32.4
# ...

# %%
new_table.count()
# Out:
# Row Label       2496
# Column label    2496
# Value           2496
# dtype: int64

# %%
new_table['country'] = new_table['Column label'].replace(to_replace= r"CIT (.*)(EST|CI )$", value = "\\1", regex=True)
new_table['measure'] = new_table['Column label'].replace(to_replace= r".* (EST|CI )$", value = "\\1", regex=True)
new_table['country'] = new_table['country'].str.lower()
new_table['country'] = new_table['country'].str.strip()
new_table['measure'] = new_table['measure'].str.lower()
new_table['measure'] = new_table['measure'].str.strip()
new_table['country'] = new_table['country'].replace(to_replace= r" ", value = "-", regex=True)
new_table['codelist'] = new_table['Column label'].str[0:4]
new_table['codelist'] = new_table['codelist'].str.lower()
new_table['Row Label'] = new_table['Row Label'].str.lower()
temp_table = new_table['Row Label'].str.split(',', -1, expand=True)
new_table['migration_flow'] = temp_table[0]
new_table['area_of_origin_or_destination'] = temp_table[1]
new_table['migration_flow'] = new_table['migration_flow'].str.strip()
new_table['migration_flow'] = new_table['migration_flow'].replace(to_replace= r" ", value = ":", regex=True)
new_table['area_of_origin_or_destination'] = new_table['area_of_origin_or_destination'].str.strip()
new_table['area_of_origin_or_destination'] = new_table['area_of_origin_or_destination'].replace(to_replace= r" ", value = "-", regex=True)
new_table['Geography'] = 'K02000001'
new_table['Unit'] = 'People (thousands)'
new_table['Measure Type'] = 'Count'
new_table['Year'] = '2016'
temp_table = new_table[:]
temp_table['Keys'] = temp_table['Row Label'] + '/' + temp_table['Column label']
temp_table['Keys'] = temp_table['Keys'].str.strip()
temp_table['Keys2'] = temp_table['Keys'].str.rstrip('EST')
temp_table['Keys2'] = temp_table['Keys2'].str.rstrip('CI')
temp_table['Keys2'] = temp_table['Keys2'].str.strip()
Final_table = pd.merge(temp_table, temp_table[['Keys2','Value','measure']], how = 'left', left_on = 'Keys2', right_on = 'Keys2')
Final_table = Final_table[Final_table['measure_x'] != Final_table['measure_y']]
Final_table = Final_table.drop_duplicates('Keys2', keep = 'first')
Final_table.columns = ['Value' if x=='Value_x' else x for x in Final_table.columns]
Final_table.columns = ['CI' if x=='Value_y' else x for x in Final_table.columns]
Final_table['Value'] = Final_table['Value'].astype(float)
Final_table['Year'] = Final_table['Year'].astype(int)
Final_table['CI'] = Final_table['CI'].astype(float)
Final_table = Final_table[['Geography','Year','codelist','country','migration_flow','area_of_origin_or_destination','Measure Type','Value','CI','Unit']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
Final_table
# Out:
#       Geography  Year codelist  country migration_flow  \
# 1     K02000001  2016     cit       all         inflow
# 3     K02000001  2016     cit       all         inflow
# 5     K02000001  2016     cit       all         inflow
# 7     K02000001  2016     cit       all         inflow
# 9     K02000001  2016     cit       all         inflow
# 11    K02000001  2016     cit       all         inflow
# 13    K02000001  2016     cit       all         inflow
# 15    K02000001  2016     cit       all         inflow
# 17    K02000001  2016     cit       all         inflow
# 19    K02000001  2016     cit       all         inflow
# 21    K02000001  2016     cit       all         inflow
# 23    K02000001  2016     cit       all         inflow
# 25    K02000001  2016     cit       all         inflow
# 27    K02000001  2016     cit       all         inflow
# 29    K02000001  2016     cit       all         inflow
# 31    K02000001  2016     cit       all        outflow
# ...

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

Final_table.to_csv(destinationFolder / ('tidydata4.04A.csv'), index = False)

# %%
writeMetadata(metadata, 'ONS-LTIM-Passenger-survey-4.04A', 'Migration')

# %%
Final_table.count()
# Out:
# Geography                        1248
# Year                             1248
# codelist                         1248
# country                          1248
# migration_flow                   1248
# area_of_origin_or_destination    1248
# Measure Type                     1248
# Value                            1248
# CI                               1248
# Unit                             1248
# dtype: int64
