# %% [markdown]
# Datasheet 4.04C: Area of destination or origin within the UK by citizenship

# %%
from databaker.framework import *
import pandas as pd

# %%
from pathlib import Path

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

# %run lib/scrape_ons.ipynb

metadata = scrape('https://www.ons.gov.uk/peoplepopulationandcommunity/populationandmigration/' \
                  'internationalmigration/datasets/ipsareaofdestinationororiginwithintheukbycitizenship')
metadata
# Out:
# {'about': 'International Passenger Survey detailed estimates of Long-Term International Migration: Area of destination or origin within the UK by citizenship. UK, Underlying datasheet 4.',
#  'fileURL': 'https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsareaofdestinationororiginwithintheukbycitizenship/2016/underlyingdatasheet4.04ipsareaofdestinationororiginwithintheukbycitizenship2016.xls',
#  'mailto': 'mailto:migstatsunit@ons.gsi.gov.uk',
#  'nextRelease': datetime.date(2018, 11, 29),
#  'releaseDate': datetime.date(2017, 11, 30),
#  'title': 'International Passenger Survey\xa04.04, area\xa0of\xa0destination or origin within the UK by citizenship'}

# %% [markdown]
# https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/populationandmigration/internationalmigration/datasets/ipsareaofdestinationororiginwithintheukbycitizenship/2016/underlyingdatasheet4.04ipsareaofdestinationororiginwithintheukbycitizenship2016.xls

# %%
inputFile = sourceFolder / 'data.xls'
response = session.get(metadata['fileURL'])
# with open(inputFile, 'wb') as f:
#   f.write(response.content)
# # tab = loadxlstabs(inputFile, sheetids='Datasheet 4.04C')[0]

# %%
# response.content

# %%
xls = pd.ExcelFile(BytesIO(response.content))
df1 = pd.read_excel(xls, 'Datasheet 4.04C', header = 7)

# %%
df1
# Out:
#            Software Readable Column Label (See Notes)  \
# 0                                              Inflow
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                            Outflow
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46      Source: Office for National Statistics (ONS).
# 47                                                NaN
# 48                Totals may not sum due to rounding.
# 49                                                NaN
# 50  "z" - Not applicable, "." - No contact, "0~" -...
# 51                                                NaN
# 52  Migration between the UK and the Republic of I...
# 53                                                NaN
# 54  1  IPS estimates for Northern Ireland are incl...
# 55                                                NaN
# 56  Citizenships for which there were no contacts ...
# 57                                                NaN
# 58  This table uses 95% confidence intervals (CI) ...
# 59                                                NaN
# 60  Published on 30 November 2017 by the Office fo...
# 61  © Crown copyright. You may re-use this informa...
# 62  To view this licence, go to: http://www.nation...
# 63  or write to the Information Policy Team, The N...
#
#                    Unnamed: 1                Unnamed: 2 Unnamed: 3  \
# 0   Country of United Kingdom           United Kingdom1  K02000001
# 1                         NaN             Great Britain  K03000001
# 2                         NaN         England and Wales  K04000001
# 3                         NaN                   England  E92000001
# 4                         NaN                     Wales  W92000004
# 5                         NaN                  Scotland  S92000003
# 6           Region of England                North East  E12000001
# 7                         NaN                North West  E12000002
# 8                         NaN  Yorkshire and The Humber  E12000003
# 9                         NaN             East Midlands  E12000004
# 10                        NaN             West Midlands  E12000005
# 11                        NaN                      East  E12000006
# 12                        NaN                    London  E12000007
# 13                        NaN                South East  E12000008
# 14                        NaN                South West  E12000009
# 15  Country of United Kingdom           United Kingdom1  K02000001
# 16                        NaN             Great Britain  K03000001
# 17                        NaN         England and Wales  K04000001
# 18                        NaN                   England  E92000001
# 19                        NaN                     Wales  W92000004
# 20                        NaN                  Scotland  S92000003
# 21          Region of England                North East  E12000001
# 22                        NaN                North West  E12000002
# 23                        NaN  Yorkshire and The Humber  E12000003
# 24                        NaN             East Midlands  E12000004
# 25                        NaN             West Midlands  E12000005
# 26                        NaN                      East  E12000006
# 27                        NaN                    London  E12000007
# 28                        NaN                South East  E12000008
# 29                        NaN                South West  E12000009
# ..                        ...                       ...        ...
# 34                        NaN                     Wales  W92000004
# 35                        NaN                  Scotland  S92000003
# 36          Region of England                North East  E12000001
# 37                        NaN                North West  E12000002
# 38                        NaN  Yorkshire and The Humber  E12000003
# 39                        NaN             East Midlands  E12000004
# 40                        NaN             West Midlands  E12000005
# 41                        NaN                      East  E12000006
# 42                        NaN                    London  E12000007
# 43                        NaN                South East  E12000008
# 44                        NaN                South West  E12000009
# 45                        NaN                       NaN        NaN
# 46                        NaN                       NaN        NaN
# 47                        NaN                       NaN        NaN
# 48                        NaN                       NaN        NaN
# 49                        NaN                       NaN        NaN
# 50                        NaN                       NaN        NaN
# 51                        NaN                       NaN        NaN
# 52                        NaN                       NaN        NaN
# 53                        NaN                       NaN        NaN
# 54                        NaN                       NaN        NaN
# 55                        NaN                       NaN        NaN
# 56                        NaN                       NaN        NaN
# 57                        NaN                       NaN        NaN
# 58                        NaN                       NaN        NaN
# 59                        NaN                       NaN        NaN
# 60                        NaN                       NaN        NaN
# 61                        NaN                       NaN        NaN
# 62                        NaN                       NaN        NaN
# 63                        NaN                       NaN        NaN
#
#                             Row Label  CIT All EST  CIT All CI  \
# 0              INFLOW, United Kingdom        526.6        34.4
# 1               INFLOW, Great Britain        520.8        33.7
# 2           INFLOW, England and Wales        488.4        32.7
# 3                     INFLOW, England        470.3        32.0
# 4                       INFLOW, Wales         18.1         6.8
# 5                    INFLOW, Scotland         32.4         8.3
# 6                  INFLOW, North East         18.9         7.8
# 7                  INFLOW, North West         43.8        10.5
# 8    INFLOW, Yorkshire and The Humber         37.7        11.7
# 9               INFLOW, East Midlands         29.0         7.8
# 10              INFLOW, West Midlands         40.4         9.0
# 11                       INFLOW, East         50.0        10.1
# 12                     INFLOW, London        143.7        14.5
# 13                 INFLOW, South East         74.3        13.9
# 14                 INFLOW, South West         32.4         8.5
# 15            OUTFLOW, United Kingdom       -315.8        23.0
# 16             OUTFLOW, Great Britain       -315.3        23.0
# 17         OUTFLOW, England and Wales       -295.1        21.8
# 18                   OUTFLOW, England       -287.6        21.6
# 19                     OUTFLOW, Wales         -7.4         2.9
# 20                  OUTFLOW, Scotland        -20.3         7.3
# 21                OUTFLOW, North East         -8.2         3.4
# 22                OUTFLOW, North West        -33.1         7.4
# 23  OUTFLOW, Yorkshire and The Humber        -16.6         4.8
# 24             OUTFLOW, East Midlands        -14.5         4.9
# 25             OUTFLOW, West Midlands        -17.6         4.3
# 26                      OUTFLOW, East        -25.6         5.7
# 27                    OUTFLOW, London       -103.9        13.4
# 28                OUTFLOW, South East        -39.9         7.6
# 29                OUTFLOW, South West        -28.2         8.0
# ..                                ...          ...         ...
# 34                     BALANCE, Wales         10.6         7.3
# 35                  BALANCE, Scotland         12.1        11.0
# 36                BALANCE, North East         10.7         8.4
# 37                BALANCE, North West         10.7        12.9
# 38  BALANCE, Yorkshire and The Humber         21.1        12.6
# 39             BALANCE, East Midlands         14.5         9.2
# 40             BALANCE, West Midlands         22.9        10.0
# 41                      BALANCE, East         24.4        11.6
# 42                    BALANCE, London         39.7        19.8
# 43                BALANCE, South East         34.5        15.8
# 44                BALANCE, South West          4.2        11.7
# 45                                NaN          NaN         NaN
# 46                                NaN          NaN         NaN
# 47                                NaN          NaN         NaN
# 48                                NaN          NaN         NaN
# 49                                NaN          NaN         NaN
# 50                                NaN          NaN         NaN
# 51                                NaN          NaN         NaN
# 52                                NaN          NaN         NaN
# 53                                NaN          NaN         NaN
# 54                                NaN          NaN         NaN
# 55                                NaN          NaN         NaN
# 56                                NaN          NaN         NaN
# 57                                NaN          NaN         NaN
# 58                                NaN          NaN         NaN
# 59                                NaN          NaN         NaN
# 60                                NaN          NaN         NaN
# 61                                NaN          NaN         NaN
# 62                                NaN          NaN         NaN
# 63                                NaN          NaN         NaN
#
#    CIT Germany EST CIT Germany CI CIT Ghana EST      ...      CIT Nepal EST  \
# 0              9.1            3.7           0.7      ...                1.4
# 1              9.1            3.7           0.7      ...                1.4
# 2              8.8            3.7           0.7      ...                1.4
# 3              6.8            3.1           0.7      ...                1.4
# 4                2            2.1             .      ...                  .
# 5              0.2            0.5             .      ...                  .
# 6              0.6            1.2           0.2      ...                  .
# 7                .              .           0.1      ...                  .
# 8              0.3            0.7             .      ...                  .
# 9              0.3            0.4             .      ...                  .
# 10             0.9            1.2           0.1      ...                  .
# 11             1.1            1.4             .      ...                0.1
# 12             2.3            1.6           0.3      ...                0.5
# 13               1            1.2           0.1      ...                0.7
# 14             0.2            0.4             .      ...                0.1
# 15            -7.8            4.3             .      ...               -0.6
# 16            -7.8            4.3             .      ...               -0.6
# 17            -6.8            3.9             .      ...               -0.6
# 18            -6.8            3.9             .      ...               -0.6
# 19               .              .             .      ...                  .
# 20            -0.9            1.8             .      ...                  .
# 21            -0.5            1.1             .      ...                  .
# 22               .              .             .      ...                  .
# 23               .              .             .      ...                  .
# 24               .              .             .      ...                  .
# 25            -0.5            0.9             .      ...                  .
# 26            -0.7            0.8             .      ...                  .
# 27            -3.6            2.8             .      ...               -0.4
# 28            -0.2            0.3             .      ...               -0.3
# 29            -1.4              2             .      ...                  .
# ..             ...            ...           ...      ...                ...
# 34               2            2.1             .      ...                  .
# 35            -0.7            1.9             .      ...                  .
# 36             0.1            1.6           0.2      ...                  .
# 37               .              .           0.1      ...                  .
# 38             0.3            0.7             .      ...                  .
# 39             0.3            0.4             .      ...                  .
# 40             0.4            1.5           0.1      ...                  .
# 41             0.5            1.6             .      ...                0.1
# 42            -1.3            3.2           0.3      ...                0.2
# 43             0.9            1.3           0.1      ...                0.4
# 44            -1.1            2.1             .      ...                0.1
# 45             NaN            NaN           NaN      ...                NaN
# 46             NaN            NaN           NaN      ...                NaN
# 47             NaN            NaN           NaN      ...                NaN
# 48             NaN            NaN           NaN      ...                NaN
# 49             NaN            NaN           NaN      ...                NaN
# 50             NaN            NaN           NaN      ...                NaN
# 51             NaN            NaN           NaN      ...                NaN
# 52             NaN            NaN           NaN      ...                NaN
# 53             NaN            NaN           NaN      ...                NaN
# 54             NaN            NaN           NaN      ...                NaN
# 55             NaN            NaN           NaN      ...                NaN
# 56             NaN            NaN           NaN      ...                NaN
# 57             NaN            NaN           NaN      ...                NaN
# 58             NaN            NaN           NaN      ...                NaN
# 59             NaN            NaN           NaN      ...                NaN
# 60             NaN            NaN           NaN      ...                NaN
# 61             NaN            NaN           NaN      ...                NaN
# 62             NaN            NaN           NaN      ...                NaN
# 63             NaN            NaN           NaN      ...                NaN
#
#    CIT Nepal CI CIT Netherlands EST CIT Netherlands CI CIT New Zealand EST  \
# 0           0.8                   6                4.8                 3.4
# 1           0.8                   6                4.8                 3.4
# 2           0.8                 5.7                4.8                 3.4
# 3           0.8                 5.7                4.8                 3.4
# 4             .                   .                  .                   .
# 5             .                 0.3                0.6                   .
# 6             .                   .                  .                   .
# 7             .                   .                  .                   .
# 8             .                   .                  .                   .
# 9             .                 0.3                0.6                   .
# 10            .                   1                  2                 0.3
# 11          0.3                   .                  .                   1
# 12          0.5                 1.5                1.7                 1.9
# 13          0.6                 2.5                  4                 0.2
# 14          0.2                 0.4                0.5                 0.1
# 15          0.6                  -4                3.8                -2.1
# 16          0.6                  -4                3.8                -2.1
# 17          0.6                  -4                3.8                -1.8
# 18          0.6                  -4                3.8                -1.8
# 19            .                   .                  .                   .
# 20            .                   .                  .                -0.3
# 21            .                -0.3                0.6                   .
# 22            .                   .                  .                   .
# 23            .                -0.2                0.4                   .
# 24            .                   .                  .                   .
# 25            .                -0.7                1.3                -0.1
# 26            .                -0.3                0.5                   .
# 27          0.4                -2.5                3.5                -1.3
# 28          0.4                   .                  .                -0.4
# 29            .                   .                  .                   .
# ..          ...                 ...                ...                 ...
# 34            .                   .                  .                   .
# 35            .                 0.3                0.6                -0.3
# 36            .                -0.3                0.6                   .
# 37            .                   .                  .                   .
# 38            .                -0.2                0.4                   .
# 39            .                 0.3                0.6                   .
# 40            .                 0.3                2.4                 0.1
# 41          0.3                -0.3                0.5                   1
# 42          0.6                  -1                3.8                 0.6
# 43          0.7                 2.5                  4                -0.2
# 44          0.2                 0.4                0.5                 0.1
# 45          NaN                 NaN                NaN                 NaN
# 46          NaN                 NaN                NaN                 NaN
# 47          NaN                 NaN                NaN                 NaN
# 48          NaN                 NaN                NaN                 NaN
# 49          NaN                 NaN                NaN                 NaN
# 50          NaN                 NaN                NaN                 NaN
# 51          NaN                 NaN                NaN                 NaN
# 52          NaN                 NaN                NaN                 NaN
# 53          NaN                 NaN                NaN                 NaN
# 54          NaN                 NaN                NaN                 NaN
# 55          NaN                 NaN                NaN                 NaN
# 56          NaN                 NaN                NaN                 NaN
# 57          NaN                 NaN                NaN                 NaN
# 58          NaN                 NaN                NaN                 NaN
# 59          NaN                 NaN                NaN                 NaN
# 60          NaN                 NaN                NaN                 NaN
# 61          NaN                 NaN                NaN                 NaN
# 62          NaN                 NaN                NaN                 NaN
# 63          NaN                 NaN                NaN                 NaN
#
#    CIT New Zealand CI CIT Nigeria EST CIT Nigeria CI CIT Norway EST  \
# 0                 1.7             6.1            3.7            3.4
# 1                 1.7             6.1            3.7            3.4
# 2                 1.7             5.5            3.6            3.4
# 3                 1.7             5.2            3.6            3.4
# 4                   .             0.3            0.5              .
# 5                   .             0.6            0.8              .
# 6                   .             0.6            1.2              .
# 7                   .               .              .              .
# 8                   .             1.4            2.7              .
# 9                   .             0.1            0.1              .
# 10                0.4             1.7            1.7              .
# 11                1.1             0.3            0.5            0.9
# 12                1.2             0.2            0.3            1.4
# 13                0.3             0.6            0.8              1
# 14                0.1             0.3            0.6              .
# 15                1.6              -1            0.9             -1
# 16                1.6              -1            0.9             -1
# 17                1.5              -1            0.9             -1
# 18                1.5              -1            0.9             -1
# 19                  .               .              .              .
# 20                0.5               .              .              .
# 21                  .            -0.3            0.6              .
# 22                  .            -0.4            0.5           -0.2
# 23                  .               .              .              .
# 24                  .               .              .              .
# 25                0.2               .              .              .
# 26                  .            -0.2            0.3              .
# 27                1.4               .              .           -0.8
# 28                0.5            -0.2            0.3              .
# 29                  .               .              .              .
# ..                ...             ...            ...            ...
# 34                  .             0.3            0.5              .
# 35                0.5             0.6            0.8              .
# 36                  .             0.3            1.3              .
# 37                  .            -0.4            0.5           -0.2
# 38                  .             1.4            2.7              .
# 39                  .             0.1            0.1              .
# 40                0.4             1.7            1.7              .
# 41                1.1             0.1            0.6            0.9
# 42                1.8             0.2            0.3            0.6
# 43                0.6             0.4            0.9              1
# 44                0.1             0.3            0.6              .
# 45                NaN             NaN            NaN            NaN
# 46                NaN             NaN            NaN            NaN
# 47                NaN             NaN            NaN            NaN
# 48                NaN             NaN            NaN            NaN
# 49                NaN             NaN            NaN            NaN
# 50                NaN             NaN            NaN            NaN
# 51                NaN             NaN            NaN            NaN
# 52                NaN             NaN            NaN            NaN
# 53                NaN             NaN            NaN            NaN
# 54                NaN             NaN            NaN            NaN
# 55                NaN             NaN            NaN            NaN
# 56                NaN             NaN            NaN            NaN
# 57                NaN             NaN            NaN            NaN
# 58                NaN             NaN            NaN            NaN
# 59                NaN             NaN            NaN            NaN
# 60                NaN             NaN            NaN            NaN
# 61                NaN             NaN            NaN            NaN
# 62                NaN             NaN            NaN            NaN
# 63                NaN             NaN            NaN            NaN
#
#    CIT Norway CI
# 0            2.6
# 1            2.6
# 2            2.6
# 3            2.6
# 4              .
# 5              .
# 6              .
# 7              .
# 8              .
# 9              .
# 10             .
# 11           1.7
# 12           1.5
# 13           1.2
# 14             .
# 15             1
# 16             1
# 17             1
# 18             1
# 19             .
# 20             .
# 21             .
# 22           0.4
# 23             .
# 24             .
# 25             .
# 26             .
# 27           0.9
# 28             .
# 29             .
# ..           ...
# 34             .
# 35             .
# 36             .
# 37           0.4
# 38             .
# 39             .
# 40             .
# 41           1.7
# 42           1.8
# 43           1.2
# 44             .
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# 52           NaN
# 53           NaN
# 54           NaN
# 55           NaN
# 56           NaN
# 57           NaN
# 58           NaN
# 59           NaN
# 60           NaN
# 61           NaN
# 62           NaN
# 63           NaN
#
# [64 rows x 89 columns]

# %%
observations = df1.iloc[:, 4:]
observations.head()
# Out:
#                    Row Label  CIT All EST  CIT All CI CIT Germany EST  \
# 0     INFLOW, United Kingdom        526.6        34.4             9.1
# 1      INFLOW, Great Britain        520.8        33.7             9.1
# 2  INFLOW, England and Wales        488.4        32.7             8.8
# 3            INFLOW, England        470.3        32.0             6.8
# 4              INFLOW, Wales         18.1         6.8               2
#
#   CIT Germany CI CIT Ghana EST CIT Ghana CI CIT Greece EST CIT Greece CI  \
# 0            3.7           0.7          0.6            4.8           3.2
# 1            3.7           0.7          0.6            4.8           3.2
# 2            3.7           0.7          0.6            4.5           3.1
# 3            3.1           0.7          0.6            4.3           3.1
# 4            2.1             .            .            0.2           0.5
#
#   CIT Guinea EST      ...      CIT Nepal EST CIT Nepal CI CIT Netherlands EST  \
# 0            0.1      ...                1.4          0.8                   6
# 1            0.1      ...                1.4          0.8                   6
# 2            0.1      ...                1.4          0.8                 5.7
# 3            0.1      ...                1.4          0.8                 5.7
# 4              .      ...                  .            .                   .
#
#   CIT Netherlands CI CIT New Zealand EST CIT New Zealand CI CIT Nigeria EST  \
# 0                4.8                 3.4                1.7             6.1
# 1                4.8                 3.4                1.7             6.1
# 2                4.8                 3.4                1.7             5.5
# 3                4.8                 3.4                1.7             5.2
# 4                  .                   .                  .             0.3
#
#   CIT Nigeria CI CIT Norway EST CIT Norway CI
# 0            3.7            3.4           2.6
# 1            3.7            3.4           2.6
# 2            3.6            3.4           2.6
# 3            3.6            3.4           2.6
# 4            0.5              .             .
#
# [5 rows x 85 columns]

# %%
new_table = pd.melt(observations,
                       ["Row Label"],
                       var_name="Column label",
                       value_name="Value")

# %%
new_table.head(50)
# Out:
#                             Row Label Column label  Value
# 0              INFLOW, United Kingdom  CIT All EST  526.6
# 1               INFLOW, Great Britain  CIT All EST  520.8
# 2           INFLOW, England and Wales  CIT All EST  488.4
# 3                     INFLOW, England  CIT All EST  470.3
# 4                       INFLOW, Wales  CIT All EST   18.1
# 5                    INFLOW, Scotland  CIT All EST   32.4
# 6                  INFLOW, North East  CIT All EST   18.9
# 7                  INFLOW, North West  CIT All EST   43.8
# 8    INFLOW, Yorkshire and The Humber  CIT All EST   37.7
# 9               INFLOW, East Midlands  CIT All EST     29
# 10              INFLOW, West Midlands  CIT All EST   40.4
# 11                       INFLOW, East  CIT All EST     50
# 12                     INFLOW, London  CIT All EST  143.7
# 13                 INFLOW, South East  CIT All EST   74.3
# 14                 INFLOW, South West  CIT All EST   32.4
# 15            OUTFLOW, United Kingdom  CIT All EST -315.8
# 16             OUTFLOW, Great Britain  CIT All EST -315.3
# 17         OUTFLOW, England and Wales  CIT All EST -295.1
# 18                   OUTFLOW, England  CIT All EST -287.6
# 19                     OUTFLOW, Wales  CIT All EST   -7.4
# 20                  OUTFLOW, Scotland  CIT All EST  -20.3
# 21                OUTFLOW, North East  CIT All EST   -8.2
# 22                OUTFLOW, North West  CIT All EST  -33.1
# 23  OUTFLOW, Yorkshire and The Humber  CIT All EST  -16.6
# 24             OUTFLOW, East Midlands  CIT All EST  -14.5
# 25             OUTFLOW, West Midlands  CIT All EST  -17.6
# 26                      OUTFLOW, East  CIT All EST  -25.6
# 27                    OUTFLOW, London  CIT All EST -103.9
# 28                OUTFLOW, South East  CIT All EST  -39.9
# 29                OUTFLOW, South West  CIT All EST  -28.2
# 30            BALANCE, United Kingdom  CIT All EST  210.8
# 31             BALANCE, Great Britain  CIT All EST  205.4
# 32         BALANCE, England and Wales  CIT All EST  193.3
# 33                   BALANCE, England  CIT All EST  182.7
# 34                     BALANCE, Wales  CIT All EST   10.6
# 35                  BALANCE, Scotland  CIT All EST   12.1
# 36                BALANCE, North East  CIT All EST   10.7
# 37                BALANCE, North West  CIT All EST   10.7
# 38  BALANCE, Yorkshire and The Humber  CIT All EST   21.1
# 39             BALANCE, East Midlands  CIT All EST   14.5
# 40             BALANCE, West Midlands  CIT All EST   22.9
# 41                      BALANCE, East  CIT All EST   24.4
# 42                    BALANCE, London  CIT All EST   39.7
# 43                BALANCE, South East  CIT All EST   34.5
# 44                BALANCE, South West  CIT All EST    4.2
# 45                                NaN  CIT All EST    NaN
# 46                                NaN  CIT All EST    NaN
# 47                                NaN  CIT All EST    NaN
# 48                                NaN  CIT All EST    NaN
# 49                                NaN  CIT All EST    NaN

# %%
new_table.shape
# Out:
# (5376, 3)

# %%
new_table.dropna(inplace=True)

# %%
new_table = new_table[new_table['Value'] != '.']

# %%
new_table = new_table[new_table['Value'] != '0']

# %%
new_table.head(50)
# Out:
#                             Row Label Column label  Value
# 0              INFLOW, United Kingdom  CIT All EST  526.6
# 1               INFLOW, Great Britain  CIT All EST  520.8
# 2           INFLOW, England and Wales  CIT All EST  488.4
# 3                     INFLOW, England  CIT All EST  470.3
# 4                       INFLOW, Wales  CIT All EST   18.1
# 5                    INFLOW, Scotland  CIT All EST   32.4
# 6                  INFLOW, North East  CIT All EST   18.9
# 7                  INFLOW, North West  CIT All EST   43.8
# 8    INFLOW, Yorkshire and The Humber  CIT All EST   37.7
# 9               INFLOW, East Midlands  CIT All EST     29
# 10              INFLOW, West Midlands  CIT All EST   40.4
# 11                       INFLOW, East  CIT All EST     50
# 12                     INFLOW, London  CIT All EST  143.7
# 13                 INFLOW, South East  CIT All EST   74.3
# 14                 INFLOW, South West  CIT All EST   32.4
# 15            OUTFLOW, United Kingdom  CIT All EST -315.8
# 16             OUTFLOW, Great Britain  CIT All EST -315.3
# 17         OUTFLOW, England and Wales  CIT All EST -295.1
# 18                   OUTFLOW, England  CIT All EST -287.6
# 19                     OUTFLOW, Wales  CIT All EST   -7.4
# 20                  OUTFLOW, Scotland  CIT All EST  -20.3
# 21                OUTFLOW, North East  CIT All EST   -8.2
# 22                OUTFLOW, North West  CIT All EST  -33.1
# 23  OUTFLOW, Yorkshire and The Humber  CIT All EST  -16.6
# 24             OUTFLOW, East Midlands  CIT All EST  -14.5
# 25             OUTFLOW, West Midlands  CIT All EST  -17.6
# 26                      OUTFLOW, East  CIT All EST  -25.6
# 27                    OUTFLOW, London  CIT All EST -103.9
# 28                OUTFLOW, South East  CIT All EST  -39.9
# 29                OUTFLOW, South West  CIT All EST  -28.2
# 30            BALANCE, United Kingdom  CIT All EST  210.8
# 31             BALANCE, Great Britain  CIT All EST  205.4
# 32         BALANCE, England and Wales  CIT All EST  193.3
# 33                   BALANCE, England  CIT All EST  182.7
# 34                     BALANCE, Wales  CIT All EST   10.6
# 35                  BALANCE, Scotland  CIT All EST   12.1
# 36                BALANCE, North East  CIT All EST   10.7
# 37                BALANCE, North West  CIT All EST   10.7
# 38  BALANCE, Yorkshire and The Humber  CIT All EST   21.1
# 39             BALANCE, East Midlands  CIT All EST   14.5
# 40             BALANCE, West Midlands  CIT All EST   22.9
# 41                      BALANCE, East  CIT All EST   24.4
# 42                    BALANCE, London  CIT All EST   39.7
# 43                BALANCE, South East  CIT All EST   34.5
# 44                BALANCE, South West  CIT All EST    4.2
# 64             INFLOW, United Kingdom   CIT All CI   34.4
# 65              INFLOW, Great Britain   CIT All CI   33.7
# 66          INFLOW, England and Wales   CIT All CI   32.7
# 67                    INFLOW, England   CIT All CI     32
# 68                      INFLOW, Wales   CIT All CI    6.8

# %%
new_table.count()
# Out:
# Row Label       1892
# Column label    1892
# Value           1892
# dtype: int64

# %%
# sourceFilename = 'column-labels-revised.csv'
# sourceFile = sourceFolder / sourceFilename
# sourceUrl = 'https://drive.google.com/uc?export=download&id=1G3tiDCLxNxyrQ95W94DXsHNMqBxv45NX'

# if not (sourceFile.exists() and sourceFile.is_file()):
#     response = requests.get(sourceUrl)
#     with open(sourceFile, 'wb') as f:
#         f.write(response.content)

# columns = pd.read_csv(sourceFile)

# %%
# sourceFilename = 'row-labels-revised.csv'
# sourceFile = sourceFolder / sourceFilename
# sourceUrl = 'https://drive.google.com/uc?export=download&id=1baA0s5L1PdbK0VPWgNde70yjGFSAeZpa'

# if not (sourceFile.exists() and sourceFile.is_file()):
#     response = requests.get(sourceUrl)
#     with open(sourceFile, 'wb') as f:
#         f.write(response.content)

# rows = pd.read_csv(sourceFile)

# %%
# columns.head()

# %%
# rows.head()

# %%
# new_table = pd.merge(new_table, columns, how = 'left', left_on = 'Column label', right_on = 'Original.Label')

# %%
# new_table.head()

# %%
# new_table = pd.merge(new_table, rows, how = 'left', left_on = 'Row Label', right_on = 'original')

# %%
new_table.head()
# Out:
#                    Row Label Column label  Value
# 0     INFLOW, United Kingdom  CIT All EST  526.6
# 1      INFLOW, Great Britain  CIT All EST  520.8
# 2  INFLOW, England and Wales  CIT All EST  488.4
# 3            INFLOW, England  CIT All EST  470.3
# 4              INFLOW, Wales  CIT All EST   18.1

# %%
new_table['Geography'] = 'K02000001'
new_table['Unit'] = 'People (thousands)'
new_table['Measure Type'] = 'Count'
new_table['Year'] = '2016'
new_table.tail()
# Out:
#                 Row Label   Column label Value  Geography                Unit  \
# 5345     BALANCE, England  CIT Norway CI   2.8  K02000001  People (thousands)
# 5349  BALANCE, North West  CIT Norway CI   0.4  K02000001  People (thousands)
# 5353        BALANCE, East  CIT Norway CI   1.7  K02000001  People (thousands)
# 5354      BALANCE, London  CIT Norway CI   1.8  K02000001  People (thousands)
# 5355  BALANCE, South East  CIT Norway CI   1.2  K02000001  People (thousands)
#
#      Measure Type  Year
# 5345        Count  2016
# 5349        Count  2016
# 5353        Count  2016
# 5354        Count  2016
# 5355        Count  2016

# %%
new_table.dtypes
# Out:
# Row Label       object
# Column label    object
# Value           object
# Geography       object
# Unit            object
# Measure Type    object
# Year            object
# dtype: object

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.count()
# Out:
# Row Label       1892
# Column label    1892
# Value           1892
# Geography       1892
# Unit            1892
# Measure Type    1892
# Year            1892
# dtype: int64

# %%
new_table.head(5)
# Out:
#                    Row Label Column label  Value  Geography  \
# 0     INFLOW, United Kingdom  CIT All EST    526  K02000001
# 1      INFLOW, Great Britain  CIT All EST    520  K02000001
# 2  INFLOW, England and Wales  CIT All EST    488  K02000001
# 3            INFLOW, England  CIT All EST    470  K02000001
# 4              INFLOW, Wales  CIT All EST     18  K02000001
#
#                  Unit Measure Type  Year
# 0  People (thousands)        Count  2016
# 1  People (thousands)        Count  2016
# 2  People (thousands)        Count  2016
# 3  People (thousands)        Count  2016
# 4  People (thousands)        Count  2016

# %%
new_table = new_table[['Geography','Year','Row Label','Column label','Measure Type','Value','Unit']]

# %%
new_table
# Out:
#       Geography  Year                          Row Label    Column label  \
# 0     K02000001  2016             INFLOW, United Kingdom     CIT All EST
# 1     K02000001  2016              INFLOW, Great Britain     CIT All EST
# 2     K02000001  2016          INFLOW, England and Wales     CIT All EST
# 3     K02000001  2016                    INFLOW, England     CIT All EST
# 4     K02000001  2016                      INFLOW, Wales     CIT All EST
# 5     K02000001  2016                   INFLOW, Scotland     CIT All EST
# 6     K02000001  2016                 INFLOW, North East     CIT All EST
# 7     K02000001  2016                 INFLOW, North West     CIT All EST
# 8     K02000001  2016   INFLOW, Yorkshire and The Humber     CIT All EST
# 9     K02000001  2016              INFLOW, East Midlands     CIT All EST
# 10    K02000001  2016              INFLOW, West Midlands     CIT All EST
# 11    K02000001  2016                       INFLOW, East     CIT All EST
# 12    K02000001  2016                     INFLOW, London     CIT All EST
# 13    K02000001  2016                 INFLOW, South East     CIT All EST
# 14    K02000001  2016                 INFLOW, South West     CIT All EST
# 15    K02000001  2016            OUTFLOW, United Kingdom     CIT All EST
# 16    K02000001  2016             OUTFLOW, Great Britain     CIT All EST
# 17    K02000001  2016         OUTFLOW, England and Wales     CIT All EST
# 18    K02000001  2016                   OUTFLOW, England     CIT All EST
# 19    K02000001  2016                     OUTFLOW, Wales     CIT All EST
# 20    K02000001  2016                  OUTFLOW, Scotland     CIT All EST
# 21    K02000001  2016                OUTFLOW, North East     CIT All EST
# 22    K02000001  2016                OUTFLOW, North West     CIT All EST
# 23    K02000001  2016  OUTFLOW, Yorkshire and The Humber     CIT All EST
# 24    K02000001  2016             OUTFLOW, East Midlands     CIT All EST
# 25    K02000001  2016             OUTFLOW, West Midlands     CIT All EST
# 26    K02000001  2016                      OUTFLOW, East     CIT All EST
# 27    K02000001  2016                    OUTFLOW, London     CIT All EST
# 28    K02000001  2016                OUTFLOW, South East     CIT All EST
# 29    K02000001  2016                OUTFLOW, South West     CIT All EST
# ...         ...   ...                                ...             ...
# 5275  K02000001  2016                    OUTFLOW, London  CIT Norway EST
# 5278  K02000001  2016            BALANCE, United Kingdom  CIT Norway EST
# 5279  K02000001  2016             BALANCE, Great Britain  CIT Norway EST
# 5280  K02000001  2016         BALANCE, England and Wales  CIT Norway EST
# 5281  K02000001  2016                   BALANCE, England  CIT Norway EST
# 5285  K02000001  2016                BALANCE, North West  CIT Norway EST
# 5289  K02000001  2016                      BALANCE, East  CIT Norway EST
# 5290  K02000001  2016                    BALANCE, London  CIT Norway EST
# 5291  K02000001  2016                BALANCE, South East  CIT Norway EST
# 5312  K02000001  2016             INFLOW, United Kingdom   CIT Norway CI
# 5313  K02000001  2016              INFLOW, Great Britain   CIT Norway CI
# 5314  K02000001  2016          INFLOW, England and Wales   CIT Norway CI
# 5315  K02000001  2016                    INFLOW, England   CIT Norway CI
# 5323  K02000001  2016                       INFLOW, East   CIT Norway CI
# 5324  K02000001  2016                     INFLOW, London   CIT Norway CI
# 5325  K02000001  2016                 INFLOW, South East   CIT Norway CI
# 5327  K02000001  2016            OUTFLOW, United Kingdom   CIT Norway CI
# 5328  K02000001  2016             OUTFLOW, Great Britain   CIT Norway CI
# 5329  K02000001  2016         OUTFLOW, England and Wales   CIT Norway CI
# 5330  K02000001  2016                   OUTFLOW, England   CIT Norway CI
# 5334  K02000001  2016                OUTFLOW, North West   CIT Norway CI
# 5339  K02000001  2016                    OUTFLOW, London   CIT Norway CI
# 5342  K02000001  2016            BALANCE, United Kingdom   CIT Norway CI
# 5343  K02000001  2016             BALANCE, Great Britain   CIT Norway CI
# 5344  K02000001  2016         BALANCE, England and Wales   CIT Norway CI
# 5345  K02000001  2016                   BALANCE, England   CIT Norway CI
# 5349  K02000001  2016                BALANCE, North West   CIT Norway CI
# 5353  K02000001  2016                      BALANCE, East   CIT Norway CI
# 5354  K02000001  2016                    BALANCE, London   CIT Norway CI
# 5355  K02000001  2016                BALANCE, South East   CIT Norway CI
#
#      Measure Type  Value                Unit
# 0           Count    526  People (thousands)
# 1           Count    520  People (thousands)
# 2           Count    488  People (thousands)
# 3           Count    470  People (thousands)
# 4           Count     18  People (thousands)
# 5           Count     32  People (thousands)
# 6           Count     18  People (thousands)
# 7           Count     43  People (thousands)
# 8           Count     37  People (thousands)
# 9           Count     29  People (thousands)
# 10          Count     40  People (thousands)
# 11          Count     50  People (thousands)
# 12          Count    143  People (thousands)
# 13          Count     74  People (thousands)
# 14          Count     32  People (thousands)
# 15          Count   -315  People (thousands)
# 16          Count   -315  People (thousands)
# 17          Count   -295  People (thousands)
# 18          Count   -287  People (thousands)
# 19          Count     -7  People (thousands)
# 20          Count    -20  People (thousands)
# 21          Count     -8  People (thousands)
# 22          Count    -33  People (thousands)
# 23          Count    -16  People (thousands)
# 24          Count    -14  People (thousands)
# 25          Count    -17  People (thousands)
# 26          Count    -25  People (thousands)
# 27          Count   -103  People (thousands)
# 28          Count    -39  People (thousands)
# 29          Count    -28  People (thousands)
# ...           ...    ...                 ...
# 5275        Count      0  People (thousands)
# 5278        Count      2  People (thousands)
# 5279        Count      2  People (thousands)
# 5280        Count      2  People (thousands)
# 5281        Count      2  People (thousands)
# 5285        Count      0  People (thousands)
# 5289        Count      0  People (thousands)
# 5290        Count      0  People (thousands)
# 5291        Count      1  People (thousands)
# 5312        Count      2  People (thousands)
# 5313        Count      2  People (thousands)
# 5314        Count      2  People (thousands)
# 5315        Count      2  People (thousands)
# 5323        Count      1  People (thousands)
# 5324        Count      1  People (thousands)
# 5325        Count      1  People (thousands)
# 5327        Count      1  People (thousands)
# 5328        Count      1  People (thousands)
# 5329        Count      1  People (thousands)
# 5330        Count      1  People (thousands)
# 5334        Count      0  People (thousands)
# 5339        Count      0  People (thousands)
# 5342        Count      2  People (thousands)
# 5343        Count      2  People (thousands)
# 5344        Count      2  People (thousands)
# 5345        Count      2  People (thousands)
# 5349        Count      0  People (thousands)
# 5353        Count      1  People (thousands)
# 5354        Count      1  People (thousands)
# 5355        Count      1  People (thousands)
#
# [1892 rows x 7 columns]

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tidydata4.04C.csv'), index = False)

# %%
writeMetadata(metadata, 'ONS-LTIM-Passenger-survey-4.04C', 'Migration')

# %%
new_table.count()
# Out:
# Geography       1892
# Year            1892
# Row Label       1892
# Column label    1892
# Measure Type    1892
# Value           1892
# Unit            1892
# dtype: int64
